# %%
import gamma_spectra_generator as gsg
import matplotlib.pyplot as plt
import importlib
importlib.reload(gsg)

# %matplotlib notebook

peaks = []
peaks.append([40, 60])
peaks.append([800, 1000])

gsg.evaluate_spectrum('cs137', peaks)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [40, 60] fit:  [8.89225853e+03 4.98373328e+01 6.06376471e+00]
# [800, 1000] fit:  [12994.19663388   896.1729677     27.0326073 ]

# %%
ch, cnts = gsg.get_spectra('cs137', calibrate=True)
plt.figure()
plt.plot(ch, cnts)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
